# %%
#!pip install scrapy
# Out:
# Collecting scrapy
#   Downloading https://files.pythonhosted.org/packages/3b/e4/69b87d7827abf03dea2ea984230d50f347b00a7a3897bc93f6ec3dafa494/Scrapy-1.8.0-py2.py3-none-any.whl (238kB)
# Collecting queuelib>=1.4.2
#   Using cached https://files.pythonhosted.org/packages/4c/85/ae64e9145f39dd6d14f8af3fa809a270ef3729f3b90b3c0cf5aa242ab0d4/queuelib-1.5.0-py2.py3-none-any.whl
# Requirement already satisfied: w3lib>=1.17.0 in d:\anaconda\envs\py35\lib\site-packages (from scrapy) (1.20.0)
# Requirement already satisfied: six>=1.10.0 in d:\anaconda\envs\py35\lib\site-packages (from scrapy) (1.12.0)
# Collecting Twisted>=17.9.0; python_version >= "3.5"
#   Downloading https://files.pythonhosted.org/packages/a6/bf/55d4735f01341f155175ff000e01bd4d7b125e86bcc68430f1dddd675cbf/Twisted-19.10.0-cp35-cp35m-win_amd64.whl (3.1MB)
# Requirement already satisfied: pyOpenSSL>=16.2.0 in d:\anaconda\envs\py35\lib\site-packages (from scrapy) (18.0.0)
# Requirement already satisfied: parsel>=1.5.0 in d:\anaconda\envs\py35\lib\site-packages (from scrapy) (1.5.1)
# Requirement already satisfied: zope.interface>=4.1.3 in d:\anaconda\envs\py35\lib\site-packages (from scrapy) (4.6.0)
# Requirement already satisfied: lxml>=3.5.0 in d:\anaconda\envs\py35\lib\site-packages (from scrapy) (4.4.1)
# Processing c:\users\avtar8\appdata\local\pip\cache\wheels\88\99\96\cfef6665f9cb1522ee6757ae5955feedf2fe25f1737f91fa7f\pydispatcher-2.0.5-cp35-none-any.whl
# Collecting protego>=0.1.15
#   Downloading https://files.pythonhosted.org/packages/e8/4b/c72e7d801facc2f519824680b65d76373e6bb289df668dbf8758ea21ff10/Protego-0.1.15.tar.gz (3.2MB)
# Requirement already satisfied: cssselect>=0.9.1 in d:\anaconda\envs\py35\lib\site-packages (from scrapy) (1.0.3)
# Requirement already satisfied: cryptography>=2.0 in d:\anaconda\envs\py35\lib\site-packages (from scrapy) (2.2.2)
# Requirement already satisfied: service-identity>=16.0.0 in d:\anaconda\envs\py35\lib\site-packages (from scrapy) (18.1.0)
# Requirement already satisfied: constantly>=15.1 in d:\anaconda\envs\py35\lib\site-packages (from Twisted>=17.9.0; python_version >= "3.5"->scrapy) (15.1.0)
# Requirement already satisfied: Automat>=0.3.0 in d:\anaconda\envs\py35\lib\site-packages (from Twisted>=17.9.0; python_version >= "3.5"->scrapy) (0.7.0)
# Requirement already satisfied: incremental>=16.10.1 in d:\anaconda\envs\py35\lib\site-packages (from Twisted>=17.9.0; python_version >= "3.5"->scrapy) (17.5.0)
# Requirement already satisfied: PyHamcrest>=1.9.0 in d:\anaconda\envs\py35\lib\site-packages (from Twisted>=17.9.0; python_version >= "3.5"->scrapy) (1.9.0)
# Requirement already satisfied: attrs>=17.4.0 in d:\anaconda\envs\py35\lib\site-packages (from Twisted>=17.9.0; python_version >= "3.5"->scrapy) (18.1.0)
# Requirement already satisfied: hyperlink>=17.1.1 in d:\anaconda\envs\py35\lib\site-packages (from Twisted>=17.9.0; python_version >= "3.5"->scrapy) (19.0.0)
# Requirement already satisfied: setuptools in c:\users\avtar8\appdata\roaming\python\python35\site-packages (from zope.interface>=4.1.3->scrapy) (41.6.0)
# Requirement already satisfied: idna>=2.1 in d:\anaconda\envs\py35\lib\site-packages (from cryptography>=2.0->scrapy) (2.6)
# Requirement already satisfied: asn1crypto>=0.21.0 in d:\anaconda\envs\py35\lib\site-packages (from cryptography>=2.0->scrapy) (0.24.0)
# Requirement already satisfied: cffi>=1.7 in d:\anaconda\envs\py35\lib\site-packages (from cryptography>=2.0->scrapy) (1.11.5)
# Requirement already satisfied: pyasn1 in d:\anaconda\envs\py35\lib\site-packages (from service-identity>=16.0.0->scrapy) (0.4.5)
# Requirement already satisfied: pyasn1-modules in d:\anaconda\envs\py35\lib\site-packages (from service-identity>=16.0.0->scrapy) (0.2.5)
# Requirement already satisfied: pycparser in d:\anaconda\envs\py35\lib\site-packages (from cffi>=1.7->cryptography>=2.0->scrapy) (2.18)
# Building wheels for collected packages: protego
#   Building wheel for protego (setup.py): started
#   Building wheel for protego (setup.py): finished with status 'done'
#   Created wheel for protego: filename=Protego-0.1.15-cp35-none-any.whl size=7740 sha256=ca884823b65c2263251f5b1059dc7e605ec4b9c2488d4605e752e8707f6ca9cb
#   Stored in directory: C:\Users\avtar8\AppData\Local\pip\Cache\wheels\72\d1\f2\4e0a2e6d0179c201952b1b3e086a736548605386193cd312f6
# Successfully built protego
# Installing collected packages: queuelib, Twisted, PyDispatcher, protego, scrapy
# Successfully installed PyDispatcher-2.0.5 Twisted-19.10.0 protego-0.1.15 queuelib-1.5.0 scrapy-1.8.0
# WARNING: You are using pip version 19.3; however, version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# Select all span elements whose class attribute equals "span-class". (Note: span is just another possible tag-name).
xpath = "//span[@class='span-class']"

# %%
# Select all paragraph p elements within the HTML
xpath = '//p'

# %% [markdown]
# Consider the HTML code:
# '''
# <html>
#   <body>
#     <div>
#       <p>Good Luck!</p>
#       <p>Not here...</p>
#     </div>
#     <div>
#       <p>Where am I?</p>
#     </div>
#   </body>
# </html>
#
# '''
# Your job will be to create an XPath string using only single forward-slashes which navigates to the paragraph p element which contains the text "Where am I?".

# %%
xpath = '/html/body/div[2]/p'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# To direct to all children of the body element!
# Create an XPath string to direct to children of body element
xpath = "/html/body/*"

# %% [markdown]
# Consider the following HTML:
#
# <html>
#   <body>
#     <div>
#       <p>Hello World!</p>
#       <div>
#         <p>Choose DataCamp!</p>
#       </div>
#     </div>
#     <div>
#       <p>Thanks for Watching!</p>
#     </div>
#   </body>
# </html>
# We have created the function print_element_text() for you, which will print the text contained in your element (if it contains any).
#
# For 2:
#
# <html>
#   <body>
#     <div id="div1" class="class-1">
#       <p class="class-1 class-2">Hello World!</p>
#       <div id="div2">
#         <p id="p2" class="class-2">Choose DataCamp!</p>
#       </div>
#     </div>
#     <div id="div3" class="class-2">
#       <p class="class-2">Thanks for Watching!</p>
#     </div>
#   </body>
# </html>

# %%
# Create an XPath string to the desired paragraph element
xpath = '/html/body/div[1]/div[1]/p[1]'

# %%
# Create an XPath string to select p element by class: xpath below to select the paragraph element containing the phrase: "Hello World!".
# Create an XPath string to select p element by class
xpath = '//p[@class="class-1 class-2"]'

# %%
# Select the path variable xpath below to select the href attribute value from the DataCamp hyperlink.

# Remember to use the double-quotation marks within the XPath attribute value. Use the @ symbol to refer to attributes.

# Create an xpath to the href attribute To get only link from a tag
xpath = '//p[@id="p2"]/a/@href'

# %% [markdown]
# Secret Links
# We have loaded the HTML from a secret website and have used it to create the functions how_many_elements() and preview(). The function how_many_elements() allows you to pass in an XPath string and it will print out the number of elements the XPath you wrote has selected. The function preview() allows you to pass in an XPath string and it will print out the first few elements you've selected.
#
# Your job in this exercise is to create an XPath which directs to all href attribute values of the hyperlink a elements whose class attributes contain the string "course-block". If you do it correctly, you should find that you have selected 40 elements with your XPath string and that it previews links (with some repetition).
#
# Fill in the blanks below to assign an XPath string to the variable xpath which directs to all href attribute values of the hyperlink a elements whose class attributes contain the string "course-block". Remember that we use the contains call within the XPath string to check if an attribute value contains a particular string.

# %%
# Create an xpath to the href attributes to select all list of Links
xpath = '//a[contains(@class,"course-block")]/@href'

# %% [markdown]
# ## Intro to Scrapy Selector

# %%
# Import Scrapy Libraries

from scrapy import Selector

# %% [markdown]
# Fill in the blank below to chain together two xpath calls which result in the same selection as
#
# sel.xpath('//div/span/p[3]')
#
# Soln:
#
# sel.xpath( '//div' ).xpath( './span/p[3]' )

# %%
# HTML Object
html = '\n<html>\n<body>\n<div>Div 1: <p>paragraph 1</p></div>\n<div>Div 2: <p>paragraph 2</p> <p>paragraph 3</p> </div>\n<div>Div 3: <p>paragraph 4</p> <p>paragraph 5</p> <p>paragraph 6</p></div>\n<div>Div 4: <p>paragraph 7</p></div>\n<div>Div 5: <p>paragraph 8</p></div>\n</body>\n</html>\n'

# %%
# Create a Selector selecting html as the HTML document
sel = Selector(text = html)

# Create a SelectorList of all div elements in the HTML document
divs = sel.xpath( "//div" )

# %%
# We move from HTML to text with the help of Requests library

# %% [markdown]
# ## Datacamp Case

# %%
url = 'https://assets.datacamp.com/production/repositories/2560/datasets/19a0a26daa8d9db1d920b5d5607c19d6d8094b3b/all_short'

# %%
# Import requests
import requests

# Create the string html containing the HTML source
html = requests.get( url ).content

# Create the Selector object sel from html
sel = Selector( text = html )

# Print out the number of elements in the HTML document
print( "There are 1020 elements in the HTML document.")
print( "You have found: ", len( sel.xpath('//*') ) )
# Out:
# There are 1020 elements in the HTML document.
# You have found:  1020

# %% [markdown]
# ## CSS Locators, Chaining, and Responses

# %%
# Create the XPath string equivalent to the CSS Locator 
xpath = '/html/body/span[1]//a'

# Create the CSS Locator string equivalent to the XPath
css_locator = 'html > body > span:nth-of-type(1) a'

# %%
# Create the XPath string equivalent to the CSS Locator 
xpath = '//div[@id="uid"]/span//h4'

# Create the CSS Locator string equivalent to the XPath
css_locator = 'div#uid > span h4'

# %%
# Assign the variable css_locator a CSS Locator string which directs to the hyperlink (a element) children of all div elements belonging to the class "course-block"

css_locator = 'div .course-block > a'

# %%
# Create the CSS Locator to all children of the element whose id is uid
css_locator = '#uid > *'

# %%
from scrapy import Selector

# Create a selector object from a secret website
sel = Selector( text = html )

# Select all hyperlinks of div elements belonging to class "course-block"
course_as = sel.css( 'div.course-block > a' )

# Selecting all href attributes chaining with css
hrefs_from_css = course_as.css( '::attr(href)' )

# Selecting all href attributes chaining with xpath
hrefs_from_xpath = course_as.xpath( './@href' )

# %%
# Create an XPath string to the desired text.
xpath = '//p[@id = "p3"]/text()'

# Create a CSS Locator string to the desired text.
css_locator = 'p#p3::text'

# Print the text from our selections
#print_results( xpath, css_locator )

# %%
# For Future Variables, we do this by

# Create an XPath string to the desired text.
xpath = '*//p[@id = "p3"]//text()'

# Create a CSS Locator string to the desired text.
css_locator = 'p#p3 ::text'

# Print the text from our selections
#print_results( xpath, css_locator )

# %%
def print_url_title( url, title ):
  print( "Here is what you found:" )
  print( "\t-URL: %s" % url )
  print( "\t-Title: %s" % title )

# %%
# Reveal by Response
# Get the URL to the website loaded in response
response = requests.get('https://www.datacamp.com/courses/all')

# %%
response
# Out:
# <Response [200]>

# %%
this_url = response.url

# Get the title of the website loaded in response
this_title = response.xpath( '/html/head/title/text()' ).extract_first()

# Print out our findings
print_url_title( this_url, this_title )

# %% [markdown]
# Assign to the variable css_locator a CSS Locator string which directs to all hyperlink a elements belonging to the class course-block__link.
#
# Assign to the variable response_as the output of passing the css_locator variable to the css method in response.
#
# Assign to the variable sel_as the output of passing the css_locator variable to the css method in sel.

# %%
# Create a CSS Locator string to the desired hyperlink elements
css_locator = 'a.course-block__link'

# Select the hyperlink elements from response and sel
response_as = response.css(css_locator)
sel_as = sel.css(css_locator)

# Examine similarity
nr = len( response_as )
ns = len( sel_as )
for i in range( min(nr, ns, 2) ):
  print( "Element %d from response: %s" % (i+1, response_as[i]) )
  print( "Element %d from sel: %s" % (i+1, sel_as[i]) )
  print( "" )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-8f1327f88f41> in <module>()
#       3
#       4 # Select the hyperlink elements from response and sel
# ----> 5 response_as = response.css(css_locator)
#       6 sel_as = sel.css(css_locator)
#       7
#
# AttributeError: 'Response' object has no attribute 'css'

# %%
# Select all desired div elements
divs = response.css('div.course-block')

# Take the first div element
first_div = divs[0]

# Extract the text from the (only) h4 element in first_div
h4_text = first_div.css("h4::text").extract_first()

# Print out the text
print( "The text from the h4 element is:", h4_text )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-dad91bcca5df> in <module>()
#       1 # Select all desired div elements
# ----> 2 divs = response.css('div.course-block')
#       3
#       4 # Take the first div element
#       5 first_div = divs[0]
#
# AttributeError: 'Response' object has no attribute 'css'

# %%
# Titular

# Create a SelectorList of the course titles
crs_title_els = response.css( 'h4::text' )

# Extract the course titles 
crs_titles = crs_title_els.extract()

# Print out the course titles 
for el in crs_titles:
  print( ">>", el )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-26b92959e042> in <module>()
#       2
#       3 # Create a SelectorList of the course titles
# ----> 4 crs_title_els = response.css( 'h4::text' )
#       5
#       6 # Extract the course titles
#
# AttributeError: 'Response' object has no attribute 'css'

# %%
# Calculate the number of children of the mystery element
how_many_kids = len( mystery.xpath( "*" ) )

# Print out the number
print( "The number of elements you selected was:", how_many_kids )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-0911bb47ec21> in <module>()
#       1 # Calculate the number of children of the mystery element
# ----> 2 how_many_kids = len( mystery.xpath( "*" ) )
#       3
#       4 # Print out the number
#       5 print( "The number of elements you selected was:", how_many_kids )
#
# NameError: name 'mystery' is not defined
